# %%
import pandas as pd

# %%
df = pd.read_json("../results/descriptors_70B_11.jsonl", lines=True)
df
# Out:
#                                               document  \
# 0    Office Manager/Editor - Seattle Office\nDawn r...
# 1    ANNCR: Over the years, Cory Gardner supported ...
# 2    Top 40 Trivia features the inspirations and fa...
# 3    product descriptionThe dress is made of severa...
# 4    slender picsat Wet-Vagina.com - page: 1\nfaces...
# ..                                                 ...
# 745  COLLOQUIUM: Shenlong Wang, "Robust Autonomy an...
# 746  March 1, 2021\nThis is the beginning of my adv...
# 747  Professional Lady in Klaipeda who can do Strip...
# 748  I’m proud to announce another patent where I a...
# 749  What is Free TON and how TON blockchain benefi...
#
#                                               doc_id  \
# 0    <urn:uuid:33321dad-edeb-47fd-9c85-745ffc29aa9a>
# 1    <urn:uuid:0927e3d7-128d-46a7-aad3-d5cf2bac96de>
# 2    <urn:uuid:d90daba8-e20d-4eed-8a67-f0dd39ed1d50>
# 3    <urn:uuid:7644b3ed-4d41-4cdd-8000-71ee33f20143>
# ...

# %%
df.similarity.mean()
# Out:
# 0.8482010666666668

# %%
df[df["similarity"] <= 0.7]
# Out:
#                                               document  \
# 14   Best friend bracelets for guys\nI like the loo...
# 23   Sat, Aug. 25, 2018 7:30pm\nSep. 8 - 9, 2018\nS...
# 26   Jetlag is a Brussels based duo combining deep,...
# 27   Using a degree or diploma is regarded as a ver...
# 46   The critera was 63% and no 10th and 12th there...
# 84   A Good Woman:\nSet in the 1930’s on the beauti...
# 91   Most Comfortable Womens Socks – If it has to d...
# 107  Download The Ugly Game: The Qatari Plot To Buy...
# 121  LONDON (Reuters) - Prime Minister Theresa May ...
# 126  Hoodia 600mg bula where to buy celebrity hoodi...
# 131  These systems operate by pushing the solvents ...
# 137  The following are benefits actual users may or...
# 150  The summer is close here in Miami and the sun ...
# 213  In need of a logo for a film and photography b...
# 239  Alfred William Pollard was a noted editor and ...
# 241  Want Wool Comic Strips - Page 75\n844 Results ...
# ...

# %%
data_types = {"document": str,
             "doc_id": str,
             "general": list,
             "specific": list,
             "rewrite": list,
             "similarity": float} 

df = df.astype(data_types) 

df.dtypes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       1 data_types = {"document": str,
#       2              "doc_id": str,
#       3              "general": list,
#       4              "specific": list,
#       5              "rewrite": list,
#       6              "similarity": float}
# ----> 8 df = df.astype(data_types)
#      10 df.dtypes
#
# File /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py:6620, in NDFrame.astype(self, dtype, copy, errors)
#    6618 else:
#    6619     try:
# -> 6620         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621     except ValueError as ex:
#    6622         ex.args = (
#    6623             f"{ex}: Error while type casting for column '{col_name}'",
#    6624         )
#
# ...
